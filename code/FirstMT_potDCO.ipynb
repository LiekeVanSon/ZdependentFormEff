# %% [markdown]
# # What is the first mass transfer case for different potential DCO systems?

# %%
import numpy as np
import os 
import pandas as pd
import h5py as h5
import matplotlib.pyplot as plt
import colorsys
from matplotlib.gridspec import GridSpec

home_dir = os.path.expanduser("~") 

home_dir = os.path.expanduser("~") 
compas_v = "v03.01.02"# "v02.46.01/"#v02.35.02/"
sim_name =  'NewWinds_RemFryer2012' #'OldWinds_RemFryer2012'#  'NewWinds_RemFryer2012_noNSBHkick'#'OldWinds_RemFryer2012'#  

datar_root = f"{home_dir}/ceph/CompasOutput/{compas_v}"

######################################
## PLOT setttings
plt.rc('font', family='serif')
from matplotlib import rc
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
fsize, SMALL_SIZE, MEDIUM_SIZE, BIGGER_SIZE = 30,20,25,30
for obj in ['axes','xtick','ytick']:
    plt.rc(obj, labelsize=SMALL_SIZE)          # controls default text sizes
for obj in ['figure','axes']:
    plt.rc(obj, titlesize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize


# Turn off natural name warning for panda tables (this is due to '@' and '>' in the COMPAS column names)
import warnings
from tables import NaturalNameWarning
warnings.filterwarnings('ignore', category=NaturalNameWarning)

######################################
# Helper function to make color darker
def darken_color(color, factor=0.8):
    r, g, b = (int(color[i:i+2], 16)/255 for i in (1, 3, 5))
    h, l, s = colorsys.rgb_to_hls(r, g, b)
    return '#%02x%02x%02x' % tuple(int(x*255) for x in colorsys.hls_to_rgb(h, l*factor, s))

# %%
####################################
# Take the base potential DCO progenitor table
prog_table_name = 'potential_DCO_progenitors_Allinfo.h5'

if os.path.isfile(datar_root+ f'/{sim_name}/'+prog_table_name):
    potential_DCO_progenitors = pd.read_hdf(f'{datar_root}/{sim_name}/' + prog_table_name, key='All_DCO')
    print('Table exists, reading in... ',  potential_DCO_progenitors.info())
else:
    print(f'error, {datar_root}/{sim_name}/{prog_table_name} does not exist, you should make it using "DataManipulation.ipynb" first')

potential_DCO_progenitors.reset_index(drop=True, inplace=True)
    

### Split your table between merging BBH/BHNS/NSNS

with h5.File(f'{datar_root}/{sim_name}/COMPAS_Output_combinedZ.h5', 'r') as All_data:
    DCO = All_data['BSE_Double_Compact_Objects']
    st1 = DCO['Stellar_Type(1)'][()]
    st2 = DCO['Stellar_Type(2)'][()]
    dco_merger = DCO['Merges_Hubble_Time'][()]  
    DCO_seed = DCO['SEED'][()]
    # Now I want to add a bool that tells me if this system is ever a BBH, BHNS or BNS progenitor
    BBH_bool = np.logical_and(st1 == 14,st2 == 14)
    BHNS_bool = np.logical_or(np.logical_and(st1 == 13,st2 == 14),
                            np.logical_and(st1 == 14,st2 == 13) )
    NSNS_bool = np.logical_and(st1 == 13,st2 == 13)
    merger_bool = dco_merger == 1

    # Split our potential DCO progenitors into BBH, BHNS and NSNS progenitors
    potential_BBH_progenitors  = potential_DCO_progenitors[np.in1d(potential_DCO_progenitors['SEED'], np.unique(DCO_seed[BBH_bool*merger_bool]) )]
    potential_BHNS_progenitors = potential_DCO_progenitors[np.in1d(potential_DCO_progenitors['SEED'], np.unique(DCO_seed[BHNS_bool*merger_bool]) )]
    potential_NSNS_progenitors = potential_DCO_progenitors[np.in1d(potential_DCO_progenitors['SEED'], np.unique(DCO_seed[NSNS_bool*merger_bool]) )]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 560052 entries, 0 to 560051
# Data columns (total 95 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SEED                                  560052 non-null  uint64
#  1   Metallicity@ZAMS(1)                   560052 non-null  float64
#  2   Stellar_Type(1)                       560052 non-null  int32
#  3   Stellar_Type(2)                       560052 non-null  int32
#  4   CE_Event_Counter                      560052 non-null  uint32
#  5   Mass@ZAMS(1)                          560052 non-null  float64
#  6   Mass@ZAMS(2)                          560052 non-null  float64
#  7   SemiMajorAxis@ZAMS                    560052 non-null  float64
#  8   Merger                                560052 non-null  uint8
#  9   Merger_At_Birth                       560052 non-null  uint8
#  10  Unbound                               560052 non-null  uint8
#  11  Immediate_RLOF>CE                     560052 non-null  uint8
#  12  Optimistic_CE                         560052 non-null  uint8
#  13  Applied_Kick_Magnitude(1)             560052 non-null  float64
#  14  Applied_Kick_Magnitude(2)             560052 non-null  float64
#  15  CH_on_MS(1)                           560052 non-null  uint8
#  16  SN_Kick_Magnitude_Random_Number(1)    560052 non-null  float64
#  17  SN_Kick_Phi(1)                        560052 non-null  float64
#  18  SN_Kick_Theta(1)                      560052 non-null  float64
#  19  SN_Kick_Mean_Anomaly(1)               560052 non-null  float64
#  20  SN_Kick_Magnitude_Random_Number(2)    560052 non-null  float64
#  21  SN_Kick_Phi(2)                        560052 non-null  float64
#  22  SN_Kick_Theta(2)                      560052 non-null  float64
#  23  SN_Kick_Mean_Anomaly(2)               560052 non-null  float64
#  24  Merges_Hubble_Time                    152404 non-null  float64
#  25  SemiMajorAxis@DCO                     152404 non-null  float64
#  26  Coalescence_Time                      152404 non-null  float64
#  27  Eccentricity@DCO                      152404 non-null  float64
#  28  MT_Donor_Hist(1)                      152404 non-null  object
#  29  MT_Donor_Hist(2)                      152404 non-null  object
#  30  Mass(1)                               152404 non-null  float64
#  31  Mass(2)                               152404 non-null  float64
#  32  unique_Z_SEED                         560052 non-null  object
#  33  firstMT_SemiMajorAxis<MT              408698 non-null  float64
#  34  firstMT_SemiMajorAxis>MT              408693 non-null  float64
#  35  firstMT_Radius(1)<MT                  408698 non-null  float64
#  36  firstMT_Radius(2)<MT                  408698 non-null  float64
#  37  firstMT_Radius(1)>MT                  408698 non-null  float64
#  38  firstMT_Radius(2)>MT                  408698 non-null  float64
#  39  firstMT_Mass(1)<MT                    408698 non-null  float64
#  40  firstMT_Mass(2)<MT                    408698 non-null  float64
#  41  firstMT_Mass(1)>MT                    408698 non-null  float64
#  42  firstMT_Mass(2)>MT                    408698 non-null  float64
#  43  firstMT_Stellar_Type(1)<MT            408698 non-null  float64
#  44  firstMT_Stellar_Type(2)<MT            408698 non-null  float64
#  45  firstMT_Stellar_Type(1)>MT            408698 non-null  float64
#  46  firstMT_Stellar_Type(2)>MT            408698 non-null  float64
#  47  firstMT_MT_Event_Counter              408698 non-null  float64
#  48  firstMT_CEE>MT                        408698 non-null  float64
#  49  firstMT_RLOF(1)>MT                    408698 non-null  float64
#  50  firstMT_RLOF(2)>MT                    408698 non-null  float64
#  51  firstMT_RLOF_Merger                   408698 non-null  float64
#  52  firstMT_M1_M2<MT                      408693 non-null  float64
#  53  MT_lead_to_merger_SemiMajorAxis<MT    99056 non-null   float64
#  54  MT_lead_to_merger_SemiMajorAxis>MT    99056 non-null   float64
#  55  MT_lead_to_merger_Radius(1)<MT        99056 non-null   float64
#  56  MT_lead_to_merger_Radius(2)<MT        99056 non-null   float64
#  57  MT_lead_to_merger_Radius(1)>MT        99056 non-null   float64
#  58  MT_lead_to_merger_Radius(2)>MT        99056 non-null   float64
#  59  MT_lead_to_merger_Mass(1)<MT          99056 non-null   float64
#  60  MT_lead_to_merger_Mass(2)<MT          99056 non-null   float64
#  61  MT_lead_to_merger_Mass(1)>MT          99056 non-null   float64
#  62  MT_lead_to_merger_Mass(2)>MT          99056 non-null   float64
#  63  MT_lead_to_merger_Stellar_Type(1)<MT  99056 non-null   float64
#  64  MT_lead_to_merger_Stellar_Type(2)<MT  99056 non-null   float64
#  65  MT_lead_to_merger_Stellar_Type(1)>MT  99056 non-null   float64
#  66  MT_lead_to_merger_Stellar_Type(2)>MT  99056 non-null   float64
#  67  MT_lead_to_merger_MT_Event_Counter    99056 non-null   float64
#  68  MT_lead_to_merger_CEE>MT              99056 non-null   float64
#  69  MT_lead_to_merger_RLOF(1)>MT          99056 non-null   float64
#  70  MT_lead_to_merger_RLOF(2)>MT          99056 non-null   float64
#  71  MT_lead_to_merger_RLOF_Merger         99056 non-null   float64
#  72  MT_lead_to_merger_M1_M2<MT            99056 non-null   float64
#  73  star2_firstMT_SemiMajorAxis<MT        237316 non-null  float64
#  74  star2_firstMT_SemiMajorAxis>MT        237311 non-null  float64
#  75  star2_firstMT_Radius(1)<MT            237316 non-null  float64
#  76  star2_firstMT_Radius(2)<MT            237316 non-null  float64
#  77  star2_firstMT_Radius(1)>MT            237316 non-null  float64
#  78  star2_firstMT_Radius(2)>MT            237316 non-null  float64
#  79  star2_firstMT_Mass(1)<MT              237316 non-null  float64
#  80  star2_firstMT_Mass(2)<MT              237316 non-null  float64
#  81  star2_firstMT_Mass(1)>MT              237316 non-null  float64
#  82  star2_firstMT_Mass(2)>MT              237316 non-null  float64
#  83  star2_firstMT_Stellar_Type(1)<MT      237316 non-null  float64
#  84  star2_firstMT_Stellar_Type(2)<MT      237316 non-null  float64
#  85  star2_firstMT_Stellar_Type(1)>MT      237316 non-null  float64
#  86  star2_firstMT_Stellar_Type(2)>MT      237316 non-null  float64
#  87  star2_firstMT_MT_Event_Counter        237316 non-null  float64
#  88  star2_firstMT_CEE>MT                  237316 non-null  float64
#  89  star2_firstMT_RLOF(1)>MT              237316 non-null  float64
#  90  star2_firstMT_RLOF(2)>MT              237316 non-null  float64
#  91  star2_firstMT_RLOF_Merger             237316 non-null  float64
#  92  star2_firstMT_M1_M2<MT                237311 non-null  float64
#  93  SN_Type(1)                            560052 non-null  float64
#  94  SN_Type(2)                            560052 non-null  float64
# dtypes: float64(82), int32(2), object(3), uint32(1), uint64(1), uint8(6)
# memory usage: 381.4+ MB
# Table exists, reading in...  None

# %%
potential_BBH_progenitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214068 entries, 0 to 560051
# Data columns (total 95 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SEED                                  214068 non-null  uint64
#  1   Metallicity@ZAMS(1)                   214068 non-null  float64
#  2   Stellar_Type(1)                       214068 non-null  int32
#  3   Stellar_Type(2)                       214068 non-null  int32
#  4   CE_Event_Counter                      214068 non-null  uint32
#  5   Mass@ZAMS(1)                          214068 non-null  float64
#  6   Mass@ZAMS(2)                          214068 non-null  float64
#  7   SemiMajorAxis@ZAMS                    214068 non-null  float64
#  8   Merger                                214068 non-null  uint8
#  9   Merger_At_Birth                       214068 non-null  uint8
#  10  Unbound                               214068 non-null  uint8
#  11  Immediate_RLOF>CE                     214068 non-null  uint8
#  12  Optimistic_CE                         214068 non-null  uint8
#  13  Applied_Kick_Magnitude(1)             214068 non-null  float64
#  14  Applied_Kick_Magnitude(2)             214068 non-null  float64
#  15  CH_on_MS(1)                           214068 non-null  uint8
#  16  SN_Kick_Magnitude_Random_Number(1)    214068 non-null  float64
#  17  SN_Kick_Phi(1)                        214068 non-null  float64
#  18  SN_Kick_Theta(1)                      214068 non-null  float64
#  19  SN_Kick_Mean_Anomaly(1)               214068 non-null  float64
#  20  SN_Kick_Magnitude_Random_Number(2)    214068 non-null  float64
#  21  SN_Kick_Phi(2)                        214068 non-null  float64
#  22  SN_Kick_Theta(2)                      214068 non-null  float64
#  23  SN_Kick_Mean_Anomaly(2)               214068 non-null  float64
#  24  Merges_Hubble_Time                    62761 non-null   float64
#  25  SemiMajorAxis@DCO                     62761 non-null   float64
#  26  Coalescence_Time                      62761 non-null   float64
#  27  Eccentricity@DCO                      62761 non-null   float64
#  28  MT_Donor_Hist(1)                      62761 non-null   object
#  29  MT_Donor_Hist(2)                      62761 non-null   object
#  30  Mass(1)                               62761 non-null   float64
#  31  Mass(2)                               62761 non-null   float64
#  32  unique_Z_SEED                         214068 non-null  object
#  33  firstMT_SemiMajorAxis<MT              143258 non-null  float64
#  34  firstMT_SemiMajorAxis>MT              143256 non-null  float64
#  35  firstMT_Radius(1)<MT                  143258 non-null  float64
#  36  firstMT_Radius(2)<MT                  143258 non-null  float64
#  37  firstMT_Radius(1)>MT                  143258 non-null  float64
#  38  firstMT_Radius(2)>MT                  143258 non-null  float64
#  39  firstMT_Mass(1)<MT                    143258 non-null  float64
#  40  firstMT_Mass(2)<MT                    143258 non-null  float64
#  41  firstMT_Mass(1)>MT                    143258 non-null  float64
#  42  firstMT_Mass(2)>MT                    143258 non-null  float64
#  43  firstMT_Stellar_Type(1)<MT            143258 non-null  float64
#  44  firstMT_Stellar_Type(2)<MT            143258 non-null  float64
#  45  firstMT_Stellar_Type(1)>MT            143258 non-null  float64
#  46  firstMT_Stellar_Type(2)>MT            143258 non-null  float64
#  47  firstMT_MT_Event_Counter              143258 non-null  float64
#  48  firstMT_CEE>MT                        143258 non-null  float64
#  49  firstMT_RLOF(1)>MT                    143258 non-null  float64
#  50  firstMT_RLOF(2)>MT                    143258 non-null  float64
#  51  firstMT_RLOF_Merger                   143258 non-null  float64
#  52  firstMT_M1_M2<MT                      143256 non-null  float64
#  53  MT_lead_to_merger_SemiMajorAxis<MT    38466 non-null   float64
#  54  MT_lead_to_merger_SemiMajorAxis>MT    38466 non-null   float64
#  55  MT_lead_to_merger_Radius(1)<MT        38466 non-null   float64
#  56  MT_lead_to_merger_Radius(2)<MT        38466 non-null   float64
#  57  MT_lead_to_merger_Radius(1)>MT        38466 non-null   float64
#  58  MT_lead_to_merger_Radius(2)>MT        38466 non-null   float64
#  59  MT_lead_to_merger_Mass(1)<MT          38466 non-null   float64
#  60  MT_lead_to_merger_Mass(2)<MT          38466 non-null   float64
#  61  MT_lead_to_merger_Mass(1)>MT          38466 non-null   float64
#  62  MT_lead_to_merger_Mass(2)>MT          38466 non-null   float64
#  63  MT_lead_to_merger_Stellar_Type(1)<MT  38466 non-null   float64
#  64  MT_lead_to_merger_Stellar_Type(2)<MT  38466 non-null   float64
#  65  MT_lead_to_merger_Stellar_Type(1)>MT  38466 non-null   float64
#  66  MT_lead_to_merger_Stellar_Type(2)>MT  38466 non-null   float64
#  67  MT_lead_to_merger_MT_Event_Counter    38466 non-null   float64
#  68  MT_lead_to_merger_CEE>MT              38466 non-null   float64
#  69  MT_lead_to_merger_RLOF(1)>MT          38466 non-null   float64
#  70  MT_lead_to_merger_RLOF(2)>MT          38466 non-null   float64
#  71  MT_lead_to_merger_RLOF_Merger         38466 non-null   float64
#  72  MT_lead_to_merger_M1_M2<MT            38466 non-null   float64
#  73  star2_firstMT_SemiMajorAxis<MT        102140 non-null  float64
#  74  star2_firstMT_SemiMajorAxis>MT        102138 non-null  float64
#  75  star2_firstMT_Radius(1)<MT            102140 non-null  float64
#  76  star2_firstMT_Radius(2)<MT            102140 non-null  float64
#  77  star2_firstMT_Radius(1)>MT            102140 non-null  float64
#  78  star2_firstMT_Radius(2)>MT            102140 non-null  float64
#  79  star2_firstMT_Mass(1)<MT              102140 non-null  float64
#  80  star2_firstMT_Mass(2)<MT              102140 non-null  float64
#  81  star2_firstMT_Mass(1)>MT              102140 non-null  float64
#  82  star2_firstMT_Mass(2)>MT              102140 non-null  float64
#  83  star2_firstMT_Stellar_Type(1)<MT      102140 non-null  float64
#  84  star2_firstMT_Stellar_Type(2)<MT      102140 non-null  float64
#  85  star2_firstMT_Stellar_Type(1)>MT      102140 non-null  float64
#  86  star2_firstMT_Stellar_Type(2)>MT      102140 non-null  float64
#  87  star2_firstMT_MT_Event_Counter        102140 non-null  float64
#  88  star2_firstMT_CEE>MT                  102140 non-null  float64
#  89  star2_firstMT_RLOF(1)>MT              102140 non-null  float64
#  90  star2_firstMT_RLOF(2)>MT              102140 non-null  float64
#  91  star2_firstMT_RLOF_Merger             102140 non-null  float64
#  92  star2_firstMT_M1_M2<MT                102138 non-null  float64
#  93  SN_Type(1)                            214068 non-null  float64
#  94  SN_Type(2)                            214068 non-null  float64
# dtypes: float64(82), int32(2), object(3), uint32(1), uint64(1), uint8(6)
# memory usage: 145.8+ MB

# %% [markdown]
# ## Plot stellar mergers for each of the DCO flavours

# %%
metallicities = np.unique(potential_DCO_progenitors['Metallicity@ZAMS(1)'])
print('metallicities', metallicities)   
Z_Zsun = np.log10(np.array(metallicities)/0.014)
# Out:
# metallicities [0.0001     0.00017321 0.0003     0.00054772 0.001      0.002
#  0.004      0.00632456 0.01       0.01414214 0.02       0.03      ]

# %%
def get_MT_numbers(table = potential_DCO_progenitors):

    # CASE A: Stellar type1/2 == 1 for star MT 1/2
    case_A_bool1    = np.logical_and(table['firstMT_Stellar_Type(1)<MT'] == 1, table['firstMT_RLOF(1)>MT'] == 1)
    case_A_bool2    = np.logical_and(table['firstMT_Stellar_Type(2)<MT'] == 1,  table['firstMT_RLOF(2)>MT'] == 1)
    case_A_bool     = np.logical_or(case_A_bool1, case_A_bool2)
    table.loc[case_A_bool, 'MT1_case_A_donor'] = True
    table.loc[~case_A_bool, 'MT1_case_A_donor'] = False

    # CASE B: Stellar type1/2 == 2 for star MT 1/2
    case_B_bool1    = np.logical_and(table['firstMT_Stellar_Type(1)<MT'] == 2, table['firstMT_RLOF(1)>MT'] == 1)
    case_B_bool2    = np.logical_and(table['firstMT_Stellar_Type(2)<MT'] == 2, table['firstMT_RLOF(2)>MT'] == 1)
    case_B_bool     = np.logical_or(case_B_bool1, case_B_bool2)
    table.loc[case_B_bool, 'MT1_case_B_donor'] = True
    table.loc[~case_B_bool, 'MT1_case_B_donor'] = False

    # CASE C: Stellar type1/2 > 2 for star MT 1/2
    case_C_bool1    = np.logical_and(table['firstMT_Stellar_Type(1)<MT'] > 2, table['firstMT_RLOF(1)>MT'] == 1)
    case_C_bool2    = np.logical_and(table['firstMT_Stellar_Type(2)<MT'] > 2, table['firstMT_RLOF(2)>MT'] == 1)
    case_C_bool     = np.logical_or(case_C_bool1, case_C_bool2)
    table.loc[case_C_bool, 'MT1_case_C_donor'] = True
    table.loc[~case_C_bool, 'MT1_case_C_donor'] = False

    # Was the mass transfer that lead to the merger, stable or unstable MT?
    firstMT_stable = table['firstMT_CEE>MT'] == 0
    # table['firstMT_stable'] = np.full(len(table), False)
    table.loc[~firstMT_stable, 'firstMT_stable'] = False
    table.loc[firstMT_stable, 'firstMT_stable'] = True

    ################################################
    grouped_byZ = table.groupby('Metallicity@ZAMS(1)')

    N_tot_DCO_prog          = grouped_byZ.size() # total number in this table (per Z)
    N_mergers               = grouped_byZ['Merger'].apply(lambda x: (x==1).sum()) # number of stellar mergers in total
    
    # print('N_mergers', N_mergers)
    # print('N_first_mt1_is_merger',N_first_mt1_is_merger, 'N_first_mt2_is_merger', N_first_mt2_is_merger)
    # print('difference: ', N_mergers - (N_first_mt1_is_merger + N_first_mt2_is_merger))

    N_optimistic_CE     = grouped_byZ['Optimistic_CE'].apply(lambda x: (x==1).sum()) # optimistic CE (= CE from case B donor)
    N_merger_at_birth   = grouped_byZ['Merger_At_Birth'].apply(lambda x: (x==1).sum()) # stars that merge at birth
    N_CHE_at_birth      = grouped_byZ['CH_on_MS(1)'].apply(lambda x: (x==1).sum()) # stars that are CHE at birth

    N_caseA_firstmt         = grouped_byZ['MT1_case_A_donor'].apply(lambda x: (x==1).sum())
    N_caseA_firstmt_stable  = grouped_byZ.apply(lambda x: ((x['MT1_case_A_donor']==1) & (x['firstMT_stable']==True)).sum())
    N_caseA_firstmt_CE      = grouped_byZ.apply(lambda x: ((x['MT1_case_A_donor']==1) & (x['firstMT_stable']==False)).sum())

    N_caseB_firstmt         = grouped_byZ['MT1_case_B_donor'].apply(lambda x: (x==1).sum())
    N_caseB_firstmt_stable  = grouped_byZ.apply(lambda x: ((x['MT1_case_B_donor']==1) & (x['firstMT_stable']==True)).sum())
    N_caseB_firstmt_CE      = grouped_byZ.apply(lambda x: ((x['MT1_case_B_donor']==1) & (x['firstMT_stable']==False)).sum())

    N_caseC_firstmt         = grouped_byZ['MT1_case_C_donor'].apply(lambda x: (x==1).sum())
    N_caseC_firstmt_stable  = grouped_byZ.apply(lambda x: ((x['MT1_case_C_donor']==1) & (x['firstMT_stable']==True)).sum())
    N_caseC_firstmt_CE      = grouped_byZ.apply(lambda x: ((x['MT1_case_C_donor']==1) & (x['firstMT_stable']==False)).sum())

    case_ABC = [N_caseA_firstmt, N_caseA_firstmt_stable, N_caseA_firstmt_CE, N_caseB_firstmt, N_caseB_firstmt_stable, N_caseB_firstmt_CE, N_caseC_firstmt, N_caseC_firstmt_stable, N_caseC_firstmt_CE]

    return  N_tot_DCO_prog, N_mergers, N_optimistic_CE, N_merger_at_birth, N_CHE_at_birth, case_ABC


N_tot_DCO_prog, N_mergers, N_optimistic_CE, N_merger_at_birth, N_CHE_at_birth, case_ABC = get_MT_numbers(table = potential_DCO_progenitors)

N_caseA_firstmt, N_caseA_firstmt_stable, N_caseA_firstmt_CE, N_caseB_firstmt, N_caseB_firstmt_stable, N_caseB_firstmt_CE, N_caseC_firstmt, N_caseC_firstmt_stable, N_caseC_firstmt_CE = case_ABC

# %%
metallicities = np.unique(potential_DCO_progenitors['Metallicity@ZAMS(1)'])
print('metallicities', metallicities)   
Z_Zsun = np.log10(np.array(metallicities)/0.014)

###########################################
# Create a figure
fig = plt.figure(figsize=(20, 5))

# Create a GridSpec with 1 row and 3 columns
gs = GridSpec(1, 3, figure=fig)

# Create 3 small subplots on a line
axes = [fig.add_subplot(gs[0, i]) for i in range(3)]

# List of panda tables of pot DCO progenitors
titles = ["BBH", "BHNS", "NSNS"]
dfs = [potential_BBH_progenitors, potential_BHNS_progenitors, potential_NSNS_progenitors]

# Loop over the axes and dataframes
for ax, df, title in zip(axes, dfs, titles):
    ax.plot(1,1)
    N_tot_DCO_prog, N_mergers, N_optimistic_CE, N_merger_at_birth, N_CHE_at_birth, case_ABC = get_MT_numbers(table = df)
    N_caseA_firstmt, N_caseA_firstmt_stable, N_caseA_firstmt_CE, N_caseB_firstmt, N_caseB_firstmt_stable, N_caseB_firstmt_CE, N_caseC_firstmt, N_caseC_firstmt_stable, N_caseC_firstmt_CE = case_ABC

    ax.plot(Z_Zsun, N_tot_DCO_prog, color='k', label='all DCO progen.', ls = '--', lw = 4,alpha = 1)

    # Normalize or abs numbers?
    norm = 1. # N_tot_DCO_prog

    bottom = np.zeros(len(Z_Zsun))

    # Stellar merger at birth 
    ax.fill_between(Z_Zsun, bottom, N_merger_at_birth, color='#959190', edgecolor='white', lw = 1, label='merger at birth', alpha = 1)
    bottom += N_merger_at_birth

    # Case A MT
    ax.fill_between(Z_Zsun, bottom, (bottom + N_caseA_firstmt_stable)/norm, color='#fdd021', edgecolor='white', hatch='/', lw = 2, label='case A stable', alpha = 1)
    bottom += N_caseA_firstmt_stable
    ax.fill_between(Z_Zsun, bottom, (bottom + N_caseA_firstmt_CE)/norm, color='#ffb13d',edgecolor='white', lw = 1, label='case A CE', alpha = 1, zorder = 10)
    bottom += N_caseA_firstmt_CE

    # Case B MT
    ax.fill_between(Z_Zsun, bottom, (bottom + N_caseB_firstmt_stable)/norm, color='#FFA570', edgecolor='white', hatch='/', lw = 1, label='case B stable', alpha = 1)
    bottom += N_caseB_firstmt_stable
    ax.fill_between(Z_Zsun, bottom, (bottom + N_caseB_firstmt_CE)/norm, color='#FF6933', edgecolor='white', lw = 1, label='case B CE', alpha = 1)
    bottom += N_caseB_firstmt_CE

    # Case C MT
    ax.fill_between(Z_Zsun, bottom, (bottom + N_caseC_firstmt_stable)/norm, color='#93ddfa', edgecolor='white', hatch='/', lw = 1, label='case C stable', alpha = 1)
    bottom += N_caseC_firstmt_stable
    ax.fill_between(Z_Zsun, bottom, (bottom + N_caseC_firstmt_CE)/norm, color='#64b2d1', edgecolor='white', lw = 1, label='case C CE', alpha = 1)
    # 284051 1B78AF
    
    # ax.plot(Z_Zsun, N_optimistic_CE, color='#BC0000', lw = 2, label='optimistic CE', alpha = 1)

    ax.set_title(f'potential merging {title}', fontsize = 22) #7x{N_tot_DCO_prog[0.0001]}
    ax.set_xlim(np.log10(1e-4/0.014),np.log10(0.03/0.014))
    ax.set_ylim(0,)
    ax.set_xlabel('log10(Z/0.014)', fontsize = 25)

#########################
# plotvalues
fig.subplots_adjust(wspace=0.15)

axes[0].set_ylabel("N first mass transfer", fontsize = 30)
axes[0].legend(bbox_to_anchor=(0.5, -0.19), loc='upper left', fontsize = 18, ncols = 4)

plt.savefig(f'../plots/{compas_v}/FirstMT_{sim_name}.pdf', bbox_inches='tight')
plt.show()
# Out:
# metallicities [0.0001     0.00017321 0.0003     0.00054772 0.001      0.002
#  0.004      0.00632456 0.01       0.01414214 0.02       0.03      ]

# %%
    # # Count Case A, B, C mass transfer
    # # What is the stellar type of the donor for the MT that lead to a stellar merger? 
    # star_1_is_RLOF = table['mergingMT_RLOF(1)>MT'] == 1
    # type_1rlof = table['mergingMT_Stellar_Type(1)<MT'][star_1_is_RLOF]

    # # When star 2 is the MT star
    # star_2_is_RLOF = table['mergingMT_RLOF(2)>MT'] == 1
    # type_2rlof = table['mergingMT_Stellar_Type(2)<MT'][star_2_is_RLOF]
    

    # # What is the stellar type of the donor for the MT that lead to a stellar merger? 
    # star_1_is_RLOF = table['mergingMT_RLOF(1)>MT'] == 1
    # type_1rlof = table['mergingMT_Stellar_Type(1)<MT'][star_1_is_RLOF]

    # # When star 2 is the MT star
    # star_2_is_RLOF = table['mergingMT_RLOF(2)>MT'] == 1
    # type_2rlof = table['mergingMT_Stellar_Type(2)<MT'][star_2_is_RLOF]
    
    # # Combine them into one array
    # type_of_MT_star = np.concatenate((type_1rlof, type_2rlof))
    # MT_type, counts = np.unique(type_of_MT_star, return_counts = True)
    # print(MT_type, counts)
    # # count the case a, b, c donors
    # case_A_donor_merger = counts[(MT_type == 0) | (MT_type == 1)].sum()
    # case_B_donor_merger = counts[MT_type == 2].sum()
    # case_C_donor_merger = counts[MT_type > 2].sum()
